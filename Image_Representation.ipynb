# %% [markdown]
# <a href="https://colab.research.google.com/github/anjalibhr04/PYTHON-PROJECTS/blob/main/Image_Representation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0=a1pha0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0=a1pha0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1)
# ERROR: No matching distribution found for tensorflow==2.0.0=a1pha0

# %%
# !pip install tensorflow-datasets

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import pandas as pd
import numpy as np
import tensorflow_datasets as tfds
import keras

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Define your model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Compile the model with the correct loss function
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4979 - accuracy: 0.8241
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3750 - accuracy: 0.8644
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3367 - accuracy: 0.8779
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3124 - accuracy: 0.8850
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2935 - accuracy: 0.8921

# %%
print(model.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_11 (Flatten)        (None, 784)               0
#
#  dense_28 (Dense)            (None, 128)               100480
#
#  dense_29 (Dense)            (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
print(tfds.list_builders())
# Out:
# ['abstract_reasoning', 'accentdb', 'aeslc', 'aflw2k3d', 'ag_news_subset', 'ai2_arc', 'ai2_arc_with_ir', 'aloha_mobile', 'amazon_us_reviews', 'anli', 'answer_equivalence', 'arc', 'asqa', 'asset', 'assin2', 'asu_table_top_converted_externally_to_rlds', 'austin_buds_dataset_converted_externally_to_rlds', 'austin_sailor_dataset_converted_externally_to_rlds', 'austin_sirius_dataset_converted_externally_to_rlds', 'bair_robot_pushing_small', 'bc_z', 'bccd', 'beans', 'bee_dataset', 'beir', 'berkeley_autolab_ur5', 'berkeley_cable_routing', 'berkeley_fanuc_manipulation', 'berkeley_gnm_cory_hall', 'berkeley_gnm_recon', 'berkeley_gnm_sac_son', 'berkeley_mvp_converted_externally_to_rlds', 'berkeley_rpt_converted_externally_to_rlds', 'big_patent', 'bigearthnet', 'billsum', 'binarized_mnist', 'binary_alpha_digits', 'ble_wind_field', 'blimp', 'booksum', 'bool_q', 'bot_adversarial_dialogue', 'bridge', 'bridge_data_msr', 'bucc', 'c4', 'c4_wsrs', 'caltech101', 'caltech_birds2010', 'caltech_birds2011', 
# ...

# %%
# Fetch the DatasetBuilder class
cvd_builder = tfds.builder("cats_vs_dogs")

# %%
# Download the dataset
cvd_builder.download_and_prepare()
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.N9IHJ8_4.0.1/cats_vs_dogs-train.tfrecord*...:   0%…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.

# %%
print(cvd_builder.info)
# Out:
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     full_name='cats_vs_dogs/4.0.1',
#     description="""
#     A large set of images of cats and dogs. There are 1738 corrupted images that are dropped.
#     """,
#     homepage='https://www.microsoft.com/en-us/download/details.aspx?id=54765',
#     data_dir=PosixGPath('/tmp/tmp3q3x5coltfds'),
#     file_format=tfrecord,
#     download_size=786.67 MiB,
#     dataset_size=1.04 GiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=uint8),
#         'image/filename': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=23262, num_shards=16>,
#     },
#     citation="""@Inproceedings (Conference){asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization,
# ...

# %%
train_ds = tfds.load("cats_vs_dogs", split=tfds.Split.TRAIN, as_supervised = True)

# %%
print(type(train_ds))
# Out:
# <class 'tensorflow.python.data.ops.prefetch_op._PrefetchDataset'>

# %%
example, = train_ds.take(1)

# %%
print(type(example))
# Out:
# <class 'tuple'>

# %%
image, label = example

# %%
print(type(image))
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
print(image.shape)
# Out:
# (262, 350, 3)

# %%
print(label.shape)
# Out:
# ()

# %%
print(label)
# Out:
# tf.Tensor(1, shape=(), dtype=int64)

# %%
print(image)
# Out:
# tf.Tensor(
# [[[251 255 255]
#   [248 254 252]
#   [242 246 245]
#   ...
#   [188 176 128]
#   [142 132  81]
#   [160 150  99]]
#
#  [[247 253 251]
#   [246 252 250]
#   [241 245 244]
#   ...
#   [188 178 129]
#   [164 154 103]
#   [176 166 115]]
#
#  [[244 249 245]
#   [244 249 245]
#   [236 241 237]
#   ...
#   [197 187 138]
#   [203 193 142]
#   [198 191 139]]
#
#  ...
#
#  [[127 124  73]
#   [149 146  95]
#   [155 152 101]
#   ...
#   [165 170 140]
#   [ 81  88  57]
#   [ 75  84  53]]
#
#  [[167 164 113]
#   [104 101  50]
#   [139 136  85]
#   ...
#   [ 67  73  45]
#   [ 48  57  28]
#   [ 38  49  19]]
#
#  [[135 132  81]
#   [ 77  74  23]
#   [135 132  81]
#   ...
#   [ 61  70  41]
#   [ 12  21   0]
#   [ 64  75  45]]], shape=(262, 350, 3), dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
train_ds = train_ds.repeat().shuffle(1024).batch(128)

# %%
print(type(train_ds))
# Out:
# <class 'tensorflow.python.data.ops.batch_op._BatchDataset'>
